# %% [markdown]
# # VIT Unimodal with Scheduler
#
# Configs:
# 1. `UNIMODAL_FEATURE_EXTRACTOR : "VIT"`
# 1. `LEARNING_RATE: 0.01`

# %%
# change present working directory to project directory
import os
os.chdir("../")

# %%
os.getcwd()
# Out:
# '/Users/shaileshmahto/Documents/Data_Science_Projects/Hate-Video-Classification/Hate_Video_Classification/CSE676-Deep-Learning-Final-Project'

# %%
import warnings
from training.test_model import test_model
from models.vision_models import LSTM
from data_preprocessing.custom_datasets import Dataset_3DCNN
from utils.utils import load_config, fix_the_random
from training.evaluation import get_metric_by_epoch, plot_all_metrics, save_results
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

# %%
warnings.filterwarnings('ignore')

model_name = "VIT_Unimodal_W_Scheduler"

config = load_config('configs/configs.yaml')
fix_the_random(2021)

# load k-fold indexes
with open(config["PICKLE_FOLDER"]+'allFoldDetails.p', 'rb') as fp:
    allDataAnnotation = pickle.load(fp)

model_cls = LSTM

dataset_cls = Dataset_3DCNN

# %% [markdown]
# ## Model Training

# %%
performance_by_epoch, best_mean_metrics, best_std_metrics = test_model(
                                                                model_cls=model_cls,
                                                                dataset_cls=dataset_cls,
                                                                epochs=config["EPOCHS"],
                                                                optimizer_name="Adam",
                                                                allDataAnnotation=allDataAnnotation
                                                            )
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# EPOCH:0, LR:[0.01]
# EPOCH:1, LR:[0.01]
# EPOCH:2, LR:[0.01]
# EPOCH:3, LR:[0.001]
# EPOCH:4, LR:[0.001]
# EPOCH:5, LR:[0.001]
# EPOCH:6, LR:[0.0001]
# EPOCH:7, LR:[0.0001]
# EPOCH:8, LR:[0.0001]
# EPOCH:9, LR:[1e-05]
# EPOCH:10, LR:[1e-05]
# EPOCH:11, LR:[1e-05]
# EPOCH:12, LR:[1.0000000000000002e-06]
# EPOCH:13, LR:[1.0000000000000002e-06]
# EPOCH:14, LR:[1.0000000000000002e-06]
# EPOCH:15, LR:[1.0000000000000002e-07]
# EPOCH:16, LR:[1.0000000000000002e-07]
# EPOCH:17, LR:[1.0000000000000002e-07]
# EPOCH:18, LR:[1.0000000000000004e-08]
#  20%|██        | 1/5 [00:49<03:16, 49.13s/it]
# EPOCH:19, LR:[1.0000000000000004e-08]
# EPOCH:0, LR:[0.01]
# EPOCH:1, LR:[0.01]
# EPOCH:2, LR:[0.01]
# EPOCH:3, LR:[0.001]
# EPOCH:4, LR:[0.001]
# EPOCH:5, LR:[0.001]
# EPOCH:6, LR:[0.0001]
# EPOCH:7, LR:[0.0001]
# EPOCH:8, LR:[0.0001]
# EPOCH:9, LR:[1e-05]
# EPOCH:10, LR:[1e-05]
# EPOCH:11, LR:[1e-05]
# EPOCH:12, LR:[1.0000000000000002e-06]
# EPOCH:13, LR:[1.0000000000000002e-06]
# EPOCH:14, LR:[1.0000000000000002e-06]
# EPOCH:15, LR:[1.0000000000000002e-07]
# EPOCH:16, LR:[1.0000000000000002e-07]
# EPOCH:17, LR:[1.0000000000000002e-07]
# EPOCH:18, LR:[1.0000000000000004e-08]
#  40%|████      | 2/5 [01:36<02:24, 48.29s/it]
# EPOCH:19, LR:[1.0000000000000004e-08]
# EPOCH:0, LR:[0.01]
# EPOCH:1, LR:[0.01]
# EPOCH:2, LR:[0.01]
# EPOCH:3, LR:[0.001]
# EPOCH:4, LR:[0.001]
# EPOCH:5, LR:[0.001]
# EPOCH:6, LR:[0.0001]
# EPOCH:7, LR:[0.0001]
# EPOCH:8, LR:[0.0001]
# EPOCH:9, LR:[1e-05]
# EPOCH:10, LR:[1e-05]
# EPOCH:11, LR:[1e-05]
# EPOCH:12, LR:[1.0000000000000002e-06]
# EPOCH:13, LR:[1.0000000000000002e-06]
# EPOCH:14, LR:[1.0000000000000002e-06]
# EPOCH:15, LR:[1.0000000000000002e-07]
# EPOCH:16, LR:[1.0000000000000002e-07]
# EPOCH:17, LR:[1.0000000000000002e-07]
# EPOCH:18, LR:[1.0000000000000004e-08]
#  60%|██████    | 3/5 [02:25<01:36, 48.34s/it]
# EPOCH:19, LR:[1.0000000000000004e-08]
# EPOCH:0, LR:[0.01]
# EPOCH:1, LR:[0.01]
# EPOCH:2, LR:[0.01]
# EPOCH:3, LR:[0.001]
# EPOCH:4, LR:[0.001]
# EPOCH:5, LR:[0.001]
# EPOCH:6, LR:[0.0001]
# EPOCH:7, LR:[0.0001]
# EPOCH:8, LR:[0.0001]
# EPOCH:9, LR:[1e-05]
# EPOCH:10, LR:[1e-05]
# EPOCH:11, LR:[1e-05]
# EPOCH:12, LR:[1.0000000000000002e-06]
# EPOCH:13, LR:[1.0000000000000002e-06]
# EPOCH:14, LR:[1.0000000000000002e-06]
# EPOCH:15, LR:[1.0000000000000002e-07]
# EPOCH:16, LR:[1.0000000000000002e-07]
# EPOCH:17, LR:[1.0000000000000002e-07]
# EPOCH:18, LR:[1.0000000000000004e-08]
#  80%|████████  | 4/5 [03:12<00:47, 47.90s/it]
# EPOCH:19, LR:[1.0000000000000004e-08]
# EPOCH:0, LR:[0.01]
# EPOCH:1, LR:[0.01]
# EPOCH:2, LR:[0.01]
# EPOCH:3, LR:[0.001]
# EPOCH:4, LR:[0.001]
# EPOCH:5, LR:[0.001]
# EPOCH:6, LR:[0.0001]
# EPOCH:7, LR:[0.0001]
# EPOCH:8, LR:[0.0001]
# EPOCH:9, LR:[1e-05]
# EPOCH:10, LR:[1e-05]
# EPOCH:11, LR:[1e-05]
# EPOCH:12, LR:[1.0000000000000002e-06]
# EPOCH:13, LR:[1.0000000000000002e-06]
# EPOCH:14, LR:[1.0000000000000002e-06]
# EPOCH:15, LR:[1.0000000000000002e-07]
# EPOCH:16, LR:[1.0000000000000002e-07]
# EPOCH:17, LR:[1.0000000000000002e-07]
# EPOCH:18, LR:[1.0000000000000004e-08]
# 100%|██████████| 5/5 [03:59<00:00, 47.89s/it]
# EPOCH:19, LR:[1.0000000000000004e-08]

# %%
with open(config["PICKLE_FOLDER"] + f"{model_name}_scores.p", "wb") as f:
    pickle.dump((performance_by_epoch, best_mean_metrics, best_std_metrics), f)

# %% [markdown]
# ## Model Evaluation

# %%
with open(config["PICKLE_FOLDER"] + f"{model_name}_scores.p", "rb") as f:
    performance_by_epoch, best_mean_metrics, best_std_metrics = pickle.load(f)

# %%
plot_all_metrics(performance_by_epoch)

# %%
name_of_entry = "VIT+LSTM+FCL+Scheduler"
save_results(performance_by_epoch, name_of_entry)
# Out:
# Results saved successfully!
